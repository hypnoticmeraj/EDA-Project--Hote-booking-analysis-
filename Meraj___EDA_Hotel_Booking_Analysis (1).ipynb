# %% [markdown]
# # **Project Name**    -  Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**   Nitish Kumar
# ##### **Team Member 2 -**   Nitin Saini
# ##### **Team Member 3 -**   Diwakar
# ##### **Team Member 4 -**   Atul Tare
# ##### **Team Member 5 -**   Md Merajuddin

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ![hotel-booking-harivansh.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/hypnoticmeraj/EDA-Project--Hote-booking-analysis-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1.   For this project we will analysing Hotel booking data. This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay , the no. of adults, children , or babies , and the number of available parking spaces.
#
# 2.   Hotel industry is a very volatile industry and the bookings depends on above factors and many more.
#
# 3.   The main objective behind this project is explore and anlyse data to discover important factor that govern the bookings and give insights to hotel management, which can perform various campaigns to boost the business and performance.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1. Generate Maximum Hotel Revenue.
# 2. Achieve Maximum Hotel Profit.
# 3. Boost Food and Beverage Revenue.
# 4. Optimize Food and Beverage Profit.
# 5. High Customer Satisfaction.
# 6. Satisfied Employees.
# 7. Busiest Hotel type

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import missingno as msno

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset 
file_path="/content/drive/MyDrive/Colab Notebooks/Dataset/Hotel Bookings.csv" 
hba_data=pd.read_csv(file_path)

# %%
# Let's create a copy of our dataset so that the original dataset does not get affected
df=hba_data.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Let's get first five rows of our dataset
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Let's get last five rows of our dataset
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Let's merge first and last seven rows of our dataframe
merged_df=pd.concat([df.head(7),df.tail(7)])
merged_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 119383    City Hotel            0        164               2017
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Let's get the shape of our dataset
df.shape
# Out:
# (119390, 32)

# %%
# Let's print the number of rows and number of columns oof our dataset
print(f' The number of rows in our dataset is {df.shape[0]}')
print(f' The number of columns in our dataset is {df.shape[1]}')
# Out:
#  The number of rows in our dataset is 119390
#  The number of columns in our dataset is 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# *   The dataframe contains 32 columns.
# *   Four columns have missing values.
# *   Some columns require conversion of datatypes.
# *   Additionally, new columns need to be added from existing ones to make analysis easier.

# %%
# Let's summarize our data in a descriptive format
df.describe().T    # Viewing in a transpose format to understand easily
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
# Let's get the datatype ofeach pf the columns
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# Let's get a quick look of our data that how many null values are present in each column of our dataset
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ### Important points to be noted here:-
# #### 1:- We see that columns like children,country,agent and commpany contains null values of total 4, 488, 16340 and 112593 respectively.
# #### 2:- Agent, company contains many high null values which might affect our data exploration and might affect the actual result. So we may drop these columns or can fill these null values with '0'.
# #### 3:- Columns like children and company also contains full null values so we fill them with their avergae values so that it does not affect our outcome.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 31994

# %%
# getting shape of duplicate values
df[df.duplicated()].shape
# Out:
# (31994, 32)

# %% [markdown]
# ##### We have in total 31994 duplicate values and we will drop these duplicate values.

# %%
# droping the duplicated values
df.drop_duplicates(inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87392 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# ##### After dropping the duplicated values, we have in total 87396 rows and 32 columns.

# %% [markdown]
# #### **Missing Values/Null Values**

# %%
# Missing Values/Null Values Count 
sum_null_values=df.isnull().sum().sort_values(ascending=False)
sum_null_values[:5]
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# dtype: int64

# %% [markdown]
# ##### We see that after removing the duplicated values, we have 82137 null values in company column, 12193 null values in agent column,  452 null values in country column and 4 null values in children column.

# %%
# Missing values percent
percent_null_values= df.isnull().mean()*100
percent_null_values.sort_values(ascending=False).round(3)[:5]
# Out:
# company               93.983
# agent                 13.951
# country                0.517
# children               0.005
# reserved_room_type     0.000
# dtype: float64

# %% [markdown]
# ##### We see that the company column contain almost 94% of null values. So, it is better to drop country column.
# Now before droping and filling all the null values, let's get a visualization of null values and see what it tell us.

# %%
# Let's visualize the null values using matrix 
msno.matrix(df)

# %% [markdown]
# ##### The matrix above show the null value in each of the row of our dataframe.
# The white horizontal line show the null values of each column of particular rows.
# We see that the column company contains the maximum null values followed by the column agent, which matches our data also.

# %% [markdown]
# #####  From the above output we can infer that we have filled all the null values from our data frame.

# %% [markdown]
# **What did you know about your dataset?**

# %% [markdown]
# In our data set we found that there are 32 columns. In these columns we have some null values and found the data type of each column. We have float64(4), int64(16), object(12) numericals columns = 20 object/categorical columns = 12

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **hotel** : Hotel(Resort Hotel or City Hotel)
#
# **is_canceled** : Value indicating if the booking was canceled (1) or not (0)
#
# **lead_time** : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# **arrival_date_year** : Year of arrival date
#
# **arrival_date_month** : Month of arrival date
#
# **arrival_date_week_number** : Week number of year for arrival date
#
# **arrival_date_day_of_month** : Day of arrival date
#
# **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# **stays_in_week_nights** : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# **adults** : Number of adults
#
# **children** : Number of children
#
# **babies** : Number of babies
#
# **meal** : Type of meal booked. Categories are presented in standard **hospitality** meal packages:
#
# **country** : Country of origin.
#
# **market_segment** : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **distribution_channel** : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **is_repeated_guest** : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# **previous_cancellations** : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# **previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer prior to the current booking
#
# **reserved_room_type** : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# **assigned_room_type** : Code for the type of room assigned to the booking.
#
# **booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# **deposit_type** : Indication on if the customer made a deposit to guarantee the booking.
#
# **agent** : ID of the travel agency that made the booking
#
# **company** : ID of the company/entity that made the booking or responsible for paying the booking.
#
# **days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# **customer_type** : Type of booking, assuming one of four categories
#
# **adr** : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# **required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# **total_of_special_requests** : Number of special requests made by the customer (e.g. twin bed or high floor)
#
# **reservation_status**: Reservation last status, assuming one of three categories
#
# **Canceled** – booking was canceled by the customer Check-Out – customer has checked in but already departed No-Show – customer did not check-in and did inform the hotel of the reason why
#
# reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("The unique values in",i, "is",df[i].nunique(),".")
# Out:
# The unique values in hotel is 2 .
# The unique values in is_canceled is 2 .
# The unique values in lead_time is 479 .
# The unique values in arrival_date_year is 3 .
# The unique values in arrival_date_month is 12 .
# The unique values in arrival_date_week_number is 53 .
# The unique values in arrival_date_day_of_month is 31 .
# The unique values in stays_in_weekend_nights is 17 .
# The unique values in stays_in_week_nights is 35 .
# The unique values in adults is 14 .
# The unique values in children is 5 .
# The unique values in babies is 5 .
# The unique values in meal is 5 .
# The unique values in country is 177 .
# The unique values in market_segment is 8 .
# The unique values in distribution_channel is 5 .
# The unique values in is_repeated_guest is 2 .
# The unique values in previous_cancellations is 15 .
# The unique values in previous_bookings_not_canceled is 73 .
# The unique values in reserved_room_type is 10 .
# The unique values in assigned_room_type is 12 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Let's count that in which year of which month most number of customers arrived at  hotel.
df.groupby(['arrival_date_month', 'arrival_date_year']).count()
# Out:
#                                       hotel  is_canceled  lead_time  \
# arrival_date_month arrival_date_year
# April              2016                3770         3770       3770
#                    2017                4138         4138       4138
# August             2015                2453         2453       2453
#                    2016                4423         4423       4423
#                    2017                4381         4381       4381
# December           2015                1982         1982       1982
#                    2016                3149         3149       3149
# February           2016                2806         2806       2806
#                    2017                3292         3292       3292
# January            2016                1849         1849       1849
#                    2017                2844         2844       2844
# July               2015                1674         1674       1674
# ...

# %% [markdown]
# # Data Cleaning
#
# Data cleaning is done to ensure that the dataset is correct, consistent and usable. It improves the efficiency and quality of analysis.

# %% [markdown]
# ## Step 1: Handle Missing Values
#
# Four out of 32 columns have missing values in them. They must be handled properly inorder to get an accurate result.

# %%
# Missing values percent
percent_null_values= df.isnull().mean()*100
percent_null_values.sort_values(ascending=False).round(3)[:5]
# Out:
# company               93.983
# agent                 13.951
# country                0.517
# children               0.005
# reserved_room_type     0.000
# dtype: float64

# %% [markdown]
# It is better to drop the column 'company' altogether since the number of missing values is extremely high compared to the number of rows.

# %%
# dropping the column 'company'
df.drop(['company'],axis=1,inplace=True)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# The number of missing values in column 'agent' is low compared to the number of rows. So, lets fill the missing values with 0 of the column 'agent'.

# %%
# Filling/replacing all the null values of the column 'agent' with the value 0.0
df['agent'].fillna(0.0, inplace = True)

# %% [markdown]
# The number of missing values in column 'country' is very low compared to the number of rows. So, lets fill the missing values with a constant string 'Others'.

# %%
# Filling/replacing all the null values of the column 'country'
# In place of null values we will put 'Others' as there might be some customer from the country whose name is not present in the given country list during time of booking.
df['country'].fillna('Others', inplace=True)

# %% [markdown]
# The number of missing values in column 'children' is negligible compared to the number of rows, so it doesn't affect the result of the analysis in a big way. Lets fill the missing values with its mean value.

# %%
# Filling/replacing all the null values of the column 'children' with its mean value
df['children'].fillna(df['children'].mean(), inplace = True)

# %%
# checking the null values again
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# Now we have successfully filled/removed all the null values of our dataset.

# %% [markdown]
# ## Step 2: Manipulation of Columns
#
# Lets add some extra columns which will come in handy during analysis.

# %%
# Let's add few columns in our dataset
df['kids']=df['babies'] + df['children']          # adding a "kids" column based on summation of no. of babies and no. of children


# Adding one more column of total_members  
df['total_members']= df['adults'] + df['kids']      # adding "total_members" by taking summation of adults and kids

# %%
# adding 'total night stays' column
df['total_night_stays']=df['stays_in_weekend_nights'] + df['stays_in_week_nights']      # adding a "total_night_stays" based on "stays_in_weekend_nights" and in "stays_in_week_nights"

# %%
# Let's add a new column 
df['arrival_date']=df['arrival_date_year'].astype(str) + '-' + df['arrival_date_month']+ '-'+ df['arrival_date_day_of_month'].astype(str)
df['arrival_date']=df['arrival_date'].apply(pd.to_datetime)

# %%
# adding 'actual guests' column
actual_guests = df.loc[df["is_canceled"] == 0]

# %%
# Adding a revenue column calculated as "adr" * "total_night_stays" 
df['revenue'] = (df['adr']) * (df['total_night_stays'])

# %%
# changing the bool data from int to string for easy representation
df['is_canceled'] = df['is_canceled'].replace([1, 0], ['cancelled', 'not cancelled'])
df['is_repeated_guest'] = df['is_repeated_guest'].replace([1, 0], ['repeated guest', 'not repeated guest'])

# %%
# Adding column which shows whether reserved room type is the same as assigned room type

df['is_reserved_room_type_assigned'] = df.apply(lambda x: 'same room type assigned' if x['reserved_room_type'] == x['assigned_room_type'] 
                                                                                                   else 'different room type assigned', axis=1)

# %%
df.head()
# Out:
#           hotel    is_canceled  lead_time  arrival_date_year  \
# 0  Resort Hotel  not cancelled        342               2015
# 1  Resort Hotel  not cancelled        737               2015
# 2  Resort Hotel  not cancelled          7               2015
# 3  Resort Hotel  not cancelled         13               2015
# 4  Resort Hotel  not cancelled         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# ## Step 3: Conversion of Column Datatype
#
# Some columns require conversion to appropriate datatypes to make analysis easier and more accurate.

# %%
# let's check columns datatype
df.dtypes
# Out:
# hotel                                     object
# is_canceled                               object
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                         object
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %% [markdown]
# ##### We see that the columns children, agents,total_members,kids,adr and revenue are float data types which does not make any sense so will convert their datatypes to int.
# Moreover, reservation_status_date is object datatype so we will convert it into datetime.

# %%
# changing datatype of children,company,agent to int
df[['children','agent','adr','revenue','kids','total_night_stays','total_members']]=df[['children','agent','adr','revenue','kids','total_night_stays','total_members']].astype(int)
# changing datatype of 'reservation_status_date' to datetime
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'], format='%Y-%m-%d')

# %%
# Let's convert datatype to str
df['arrival_date_year'] = df['arrival_date_year'].astype('str')
df['arrival_date_month'] = df['arrival_date_month'].astype('str')
df['arrival_date_day_of_month'] = df['arrival_date_day_of_month'].astype('str')
df['is_canceled'] = df['is_canceled'].astype('str')
df['is_repeated_guest'] = df['is_repeated_guest'].astype('str')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# #### There are many rows that contains 0 adults that does not makenany sensse. So we will remove those rows.

# %%
# Let's drop the rows which contain 0 values in adults,babies,children
df = df.drop(df[(df.adults+df.babies+df.children)==0].index) 
df=df.drop(df[(df.adults)==0].index)

# %%
# Let's drop total_night_stays=0
df=df.drop(df[df['total_night_stays']==0].index)

# %%
# Dataset Describe
cols_want=['total_members','adults','kids','adr','agent','lead_time','booking_changes','total_night_stays'] 
df[cols_want].describe().T   # Getting the transpose view to understand easily
# Out:
#                      count        mean         std  min   25%   50%    75%  \
# total_members      86420.0    2.030629    0.791579  1.0   2.0   2.0    2.0
# adults             86420.0    1.885270    0.615805  1.0   2.0   2.0    2.0
# kids               86420.0    0.145360    0.463430  0.0   0.0   0.0    0.0
# adr                86420.0  107.072125   54.387408 -6.0  72.0  99.0  134.0
# agent              86420.0   81.146135  109.997698  0.0   9.0   9.0  240.0
# lead_time          86420.0   80.184517   86.022815  0.0  12.0  50.0  125.0
# booking_changes    86420.0    0.267924    0.709598  0.0   0.0   0.0    0.0
# total_night_stays  86420.0    3.653471    2.737567  1.0   2.0   3.0    5.0
#
#                       max
# total_members        55.0
# adults               55.0
# kids                 10.0
# adr                5400.0
# agent               535.0
# lead_time           709.0
# booking_changes      18.0
# total_night_stays    69.0

# %% [markdown]
# #### **Quick observation**
#
# 1.   The average total night stays is 3.62
# 2.   Highest total nights stay is 69
# 3.   On an average 81 guests book their hotels through agent
# 4.   Average lead time is 80 days
# 5.   On an average there is very low guests who have cancelled their bookings
# 6.   In each bookings on an average there are 1.8 adults and 0.15 kids

# %% [markdown]
# Before doing Data Visualization, let's find out the outliers (if any) in our dataset.

# %%
# Let's check outliers in few of our columns
plt.figure(figsize=(30,16))
sns.boxplot(data=df[['adr','lead_time','stays_in_weekend_nights','stays_in_week_nights', 'adults','children','babies', 'booking_changes']])
plt.show()

# %% [markdown]
# We can see that column 'adr' has a very high outlier so we will remove those outliers.

# %%
# removing outliers from 'adr' column
df.drop(df[df['adr'] <= 0].index, inplace = True)
df.drop(df[df['adr']>5000].index, inplace=True)

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Univariate Analysis** :- Univariate analysis is the simplest form of analyzing data i.e study of one variable. Its major purpose is to describe; distribution of single data, and find patterns in the data.

# %% [markdown]
# ###**1 :-**  **How many Total bookings are there in both type of Hotels?**

# %%
# Let's see the no. of bookings in each type of hotel
hotel_wise_bookings=df['hotel'].value_counts() 
hotel_wise_bookings
# Out:
# City Hotel      52106
# Resort Hotel    33264
# Name: hotel, dtype: int64

# %% [markdown]
# ##### From the above data, it is clearly seen that City Hotel has most highest number of bookings of total 53274 and Resort Hotel has total bookings of 33956.
# Let's now visualize it by bar chart and pie chart.

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(15,8))
fig, axes = plt.subplots(1,2, figsize=(10, 4))

sns.countplot(ax=axes[0],data=df,x='hotel',palette=['salmon', 'black'],edgecolor='grey')          # setting color to salmon and black, setting edge color to black
plt.title('Total booking hotel wise',fontsize = 20, fontweight='bold')         # setting title - fontsize to 20 and in bold
plt.ylabel('No. of bookings', fontsize=15)               # setting y_label
plt.xlabel('Hotel Type', fontsize = 15)                  # setting x_label 

# getting the same in percentage terms by using pie chart
hotel_wise_bookings.plot(kind='pie',ax=axes[1],autopct='%1.1f%%',labels=None,figsize=(15,8),fontsize=18,colors=['tab:green','tab:red'])
plt.title('Total Booking Hotel Wise (in %)',fontsize = 20, fontweight='bold')          # setting title
plt.legend(loc='upper right',labels=df['hotel'].value_counts().index.tolist())        # setting legend

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we chose bar graph and pie chart to show the total number of bookings for each hotel types.Pie Chart is useful in comparing two numerical values in a percentage form and Bar Chart is useful as it shows the value of of different categories.
# A bar graph is used to give the comparison between two or more categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above bar chart it is clear that City Hotel has most number of bookings of 53274 and Resort Hotel has total bookings of 33956.
#  We see that City Hotel has highest number of bookings of 61.2% and Resort Hotel acquire 38.8% of total bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City Hotel acquired highest number of bookings as it might be that City Hotels are located in city and due to business and other reasons their bookings are usually high. Resort Hotel have less number of bookings as it is mosstly located outside of city and people mostly choose Resort Hotel for longer vaccation.

# %% [markdown]
# ###2:- **Cancelation Status by Hotel Type**

# %%
cancelation_status=df[['is_canceled','hotel']].value_counts().reset_index()
cancelation_status
# Out:
#      is_canceled         hotel      0
# 0  not cancelled    City Hotel  36248
# 1  not cancelled  Resort Hotel  25363
# 2      cancelled    City Hotel  15858
# 3      cancelled  Resort Hotel   7901

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(15,8))     # setting figure size
sns.set_palette('terrain')      # setting color
hotel_booking_each_year=sns.countplot(x='hotel',hue='is_canceled', data=df, edgecolor='black')  

plt.title('Cancelation Status by Hotel Type',fontsize = 20, fontweight='bold')    # setting title
plt.legend(loc='upper right',labels=['canceled','not-canceled'])         # setting legend
plt.xlabel('Hotel Type',fontsize = 15)        # setting x-label
plt.ylabel('Count',fontsize = 15)             # setting x-label
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Multiple bar charts are very useful for comparing the same items in different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  In both the hotel type, the proportion of cancellation is more than the confirmed status.Moreover, cancelation is less in Resort Hotel compared to City Hotel.This may be due to City hotel's higher number of bookings compared to Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In order to reduce the booking cancellations hotels need to set the refundable/ no refundable and deposit policies policies.

# %% [markdown]
# ###**3:- How many repeated guests are there in each type of Hotel?**

# %%
City_Hotel=df[df['hotel']=='City Hotel']
City_Hotel
# Out:
#              hotel    is_canceled  lead_time arrival_date_year  \
# 40061   City Hotel      cancelled         88              2015
# 40062   City Hotel      cancelled         65              2015
# 40063   City Hotel      cancelled         92              2015
# 40064   City Hotel      cancelled        100              2015
# 40065   City Hotel      cancelled         79              2015
# ...            ...            ...        ...               ...
# 119385  City Hotel  not cancelled         23              2017
# 119386  City Hotel  not cancelled        102              2017
# 119387  City Hotel  not cancelled         34              2017
# 119388  City Hotel  not cancelled        109              2017
# 119389  City Hotel  not cancelled        205              2017
#
#        arrival_date_month  arrival_date_week_number arrival_date_day_of_month  \
# 40061                July                        27                         1
# ...

# %%
Resort=df[df['hotel']=='Resort Hotel']
Resort
# Out:
#               hotel    is_canceled  lead_time arrival_date_year  \
# 2      Resort Hotel  not cancelled          7              2015
# 3      Resort Hotel  not cancelled         13              2015
# 4      Resort Hotel  not cancelled         14              2015
# 6      Resort Hotel  not cancelled          0              2015
# 7      Resort Hotel  not cancelled          9              2015
# ...             ...            ...        ...               ...
# 40055  Resort Hotel  not cancelled        212              2017
# 40056  Resort Hotel  not cancelled        169              2017
# 40057  Resort Hotel  not cancelled        204              2017
# 40058  Resort Hotel  not cancelled        211              2017
# 40059  Resort Hotel  not cancelled        161              2017
#
#       arrival_date_month  arrival_date_week_number arrival_date_day_of_month  \
# 2                   July                        27                         1
# ...

# %%
resort_count=Resort['is_repeated_guest'].value_counts()
city_count=City_Hotel['is_repeated_guest'].value_counts()

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
fig, axes = plt.subplots(1,2, figsize=(36, 8))
ax=city_count.plot(kind='pie',ax=axes[1],autopct='%1.1f%%',labels=None,figsize=(15,8),fontsize=18)# colors=['tab:green','tab:red'])
ax.set_title('Repeated Guest in City Hotel(in %)',fontweight='bold',fontsize=15)
ax.legend(loc='upper right',labels=['not-repeated','repeated'])
ax=resort_count.plot(kind='pie',ax=axes[0],autopct='%1.1f%%',labels=None,figsize=(15,8),fontsize=18,colors=['tab:pink','tab:grey'])
ax.set_title('Repeated Guest in Resort Hotel(in %)',fontweight='bold',fontsize=15)
ax.legend(loc='upper right',labels=['not-repeated','repeated'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we chose pie chart to depicit the percentage of repeated guest in both type of hotel. Since pie chart is very useful in doing comparision between variables in percentage format.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that in both type of Hotel there is only litte percentage of repeated guests.
#
# In City Hotel there is only 2.9% of repeated guests and in Resort Hotel there is only 4.8% of repeated guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insights lead to negative growth as there are minimal amount of repeated guests in both types of hotel.

# %% [markdown]
# ####4: **Which agents has made highest bookings?**

# %%
# let's write a function for value_count
def add_value_label(x_list,y_list):
  # "it add values to top of each bar"
    for i in range(1, len(x_list)+1):
        plt.text(i-1,y_list[i-1],y_list[i-1], ha="center", fontweight='bold')

# %%
highest_bookings_by_agent=df.groupby('agent')['agent'].agg({'count'}).reset_index().rename(columns={'count':'most_booking'}).sort_values(by='most_booking',ascending=False)
highest_bookings_by_agent
# Out:
#      agent  most_booking
# 9        9         28468
# 174    240         12900
# 0        0         11290
# 14      14          3312
# 7        7          3276
# ..     ...           ...
# 250    352             1
# 53      59             1
# 79      90             1
# 209    289             1
# 205    285             1
#
# [333 rows x 2 columns]

# %%
# We have seen earlier that agent 0 contains null values which we filled by 0 so it's better to just drop agent 0
highest_bookings_by_agent.drop(highest_bookings_by_agent[highest_bookings_by_agent['agent']==0].index,inplace=True)
# Let's get the graph for top 5 agents
top_five=highest_bookings_by_agent[:5]
top_five
# Out:
#      agent  most_booking
# 9        9         28468
# 174    240         12900
# 14      14          3312
# 7        7          3276
# 183    250          2765

# %% [markdown]
# #### Chart - 4

# %%
# Chart -4 visualization code 
plt.figure(figsize=(15,8))                  # setting figure size
sns.set_palette('PRGn')                     # setting figure color
sns.barplot(x=top_five['agent'],y=top_five['most_booking'],order=top_five['agent'],edgecolor='black')
add_value_label(top_five['agent'].tolist(), top_five['most_booking'].tolist())
plt.title('Most bookings by agent',fontsize=20,fontweight='bold')                # setting title
plt.xlabel('Agent ID',fontsize=15)                                               # setting x-label
plt.ylabel('No. of bookings',fontsize=15)                                        # setting y-label
# Out:
# Text(0, 0.5, 'No. of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar graph is used to give the comparison between two or more categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above graph shows top 5 Agent with highest number of bookings. The top five Agents are  Agent 9, Agent 240, Agent 14, Agent 7, Agent 250.Agent 9 has done the highest booking of 28654.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gain insights will help creating a positive business impact as now the Agent which has done low amount of bookings should be given more training off how to approach and convience the customers to book their Hotel rooms thorugh agents.

# %% [markdown]
# ###**5:- How many bookings made in each year for each Hotel type?**

# %%
df[['hotel','arrival_date_year']].value_counts().reset_index().rename(columns={'arrival_date_year':'year',0:'Count of bookings'})
# Out:
#           hotel  year  Count of bookings
# 0    City Hotel  2016              26109
# 1    City Hotel  2017              19783
# 2  Resort Hotel  2016              15272
# 3  Resort Hotel  2017              11414
# 4  Resort Hotel  2015               6578
# 5    City Hotel  2015               6214

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code 
# This graph shows the booking made in each month for different hotel types   
plt.figure(figsize=(15,8))     # setting figure size
sns.set_palette('PRGn')                     # setting color
hotel_booking_each_year=sns.countplot(x='arrival_date_year',hue='hotel',data=df,edgecolor='black')   
plt.title('Bookings Made in each Year for Each Hotel Type',fontsize = 20, fontweight='bold')         # setting title
plt.xlabel('Year',fontsize = 15)                  # setting x-label
plt.ylabel('Reservation Count',fontsize = 15)     # setting y-label
# Out:
# Text(0, 0.5, 'Reservation Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Multiple bar charts are very useful for comparing the same items in different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that the year 2016 has highest number of bookings, followed by 2017 and then 2015.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows that may be due to less Hotel promotions or maybe due to financial criss the number of bookings have been decreased in 2017.

# %% [markdown]
# ###**6:- How many bookings are there in each month and for each Hotel type?**

# %%
df[['hotel','arrival_date_month']].value_counts().reset_index().rename(columns={'arrival_date_month':'month',0:'Count of bookings'})
# Out:
#            hotel      month  Count of bookings
# 0     City Hotel     August               6447
# 1     City Hotel       July               5615
# 2     City Hotel        May               5314
# 3     City Hotel      April               4991
# 4     City Hotel       June               4916
# 5     City Hotel      March               4750
# 6   Resort Hotel     August               4622
# 7   Resort Hotel       July               4254
# 8     City Hotel  September               4116
# 9     City Hotel    October               4072
# 10    City Hotel   February               3496
# 11    City Hotel   December               2894
# 12  Resort Hotel        May               2880
# 13    City Hotel   November               2845
# 14  Resort Hotel      April               2773
# 15  Resort Hotel       June               2723
# 16    City Hotel    January               2650
# 17  Resort Hotel    October               2640
# 18  Resort Hotel      March               2598
# ...

# %%
# Let's arrange the months in month order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['arrival_date_month']=pd.Categorical(df['arrival_date_month'],categories=months,ordered=True)

# %%
# Chart - 6 visualization code
plt.figure(figsize=(15,8))     # setting figure size
sns.set_palette('terrain')      # setting color
sns.countplot(x='arrival_date_month',hue='hotel',data=df,edgecolor='black')   
plt.title('Bookings Made in Each Month for Each Hotel Type',fontweight='bold',fontsize=20)
plt.xlabel('Month',fontsize = 15)                 # setting x-label
plt.ylabel('Reservation Count',fontsize = 15)     # setting y-label
# Out:
# Text(0, 0.5, 'Reservation Count')

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
#  Multiple bar charts are very useful for comparing the same items in different months.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that month of August has highest number of bookings for both City Hotel and Resort Hotel, followed by the month of July. December and Janauray have lowest recorded lowest amount of bookings.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# December and January have lowest amount of bookings. It might be due to at this time Hotel keeps their prices very high.

# %% [markdown]
# ### **7:-** **Top five countries with maximum number of visitors**

# %%
count_country=df['country'].value_counts().sort_values(ascending=False).reset_index().rename(columns={'index':'country','country':'count of travelers'})
count_country_top_five=count_country[:5]
count_country_top_five
# Out:
#   country  count of travelers
# 0     PRT               25987
# 1     GBR               10344
# 2     FRA                8761
# 3     ESP                7167
# 4     DEU                5353

# %% [markdown]
# ##### From the above table it can be seen that the top five countries where most traveler are coming from are PRT (Portugal), GBR(United Kingdom), FRA(France), ESP(Spain) and DEU(Germany). Portugal have highest number of visitors followed by United Kingdom.
# ##### Let's now show the same using bar chart

# %%
# Chart - 7 visualization code
plt.figure(figsize=(15,8))
sns.set_palette('terrain') 
sns.barplot(x=count_country_top_five['country'],y=count_country_top_five['count of travelers'],order=count_country_top_five['country'],edgecolor='black')
add_value_label(count_country_top_five['country'].tolist(), count_country_top_five['count of travelers'].tolist())
plt.title('Top five countries with maximum number of bookings', fontsize=20,fontweight='bold')
plt.xlabel('Country', fontsize=15)
plt.ylabel('No. of  bookings', fontsize=15)
# Out:
# Text(0, 0.5, 'No. of  bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar graph is used to give the comparison between two or more categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top five countries are PRT(Portugal), GBR(United Kingdom), FRA(France), ESP(Spain) and DEU(Germany). Highest number of visitors are coming from Portugal followed by United Kingdom.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This bar is really helpful in showing the top five countries with maximum visitors. Through this chart it can be say that most of the visitors is from European countries and the Hotels needs to work more towards attracting the Non-European counntries visitors.

# %% [markdown]
# ### 8:- **Which channel is mostly used for early booking of hotels?**

# %%
segments=df['market_segment'].value_counts()
segments
# Out:
# Online TA        51062
# Offline TA/TO    13623
# Direct           11545
# Groups            4719
# Corporate         4136
# Aviation           222
# Complementary       61
# Undefined            2
# Name: market_segment, dtype: int64

# %% [markdown]
# Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
segments.plot(kind='barh',figsize=(15,8))
plt.title('Bookings by Market Segment',fontsize=20,fontweight='bold')      # setting title
plt.xlabel('Market Segment',fontsize = 15)        # setting x-label
plt.ylabel('Count',fontsize = 15)          # setting x-label
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we used horizontal bar graph to show different ctegories values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Around  51285 of bookings are made via Online Travel Agents, almost 13749 of bookings are made via Offline Travel Agents and the rest are Direct bookings without any other agents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###**9:- What are the market share of different customers?**

# %%
customer_market_share=df['customer_type'].value_counts() 
customer_market_share
# Out:
# Transient          70476
# Transient-Party    11271
# Contract            3114
# Group                509
# Name: customer_type, dtype: int64

# %% [markdown]
# Most of the bookings are through online agent mode as it might be easier to done booking via online by agent than to directly book thorugh Hotel official website.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
customer_market_share.plot(kind='pie',figsize=(15,8),autopct='%1.1f%%',labels=None)
plt.title('Market share of customers (By %)', fontsize=20, fontweight='bold')       # setting title
plt.legend(loc='upper right',labels=df['customer_type'].value_counts().index.tolist())  # setting legend

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we used pie chart as it shows percentage share of each customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient Customer type captured highest bookings share of around 82% and then followed by Transient-Party . Group type has captured only negligible amount of 0.6%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###**10:- Bookings based on Total Night Stays**

# %%
count_of_night_bookings=df['total_night_stays'].value_counts()[:10].reset_index().rename(columns={'index':'night stays','total_night_stays':'No. of bookings'})
count_of_night_bookings
# Out:
#    night stays  No. of bookings
# 0            3            17655
# 1            1            16658
# 2            2            15393
# 3            4            13457
# 4            7             7485
# 5            5             6689
# 6            6             3239
# 7           10             1069
# 8            8             1052
# 9           14              856

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(15,8))
sns.barplot(x=count_of_night_bookings['night stays'],y=count_of_night_bookings['No. of bookings'],order=count_of_night_bookings['night stays'],edgecolor='black')
add_value_label(count_of_night_bookings['night stays'].tolist(), count_of_night_bookings['No. of bookings'].tolist())
plt.title('Bookings Based On Total Night Stays', fontsize=20,fontweight='bold')   # setting title
plt.xlabel('Nights', fontsize=15)           # setting x-label
plt.ylabel('No. of  bookings', fontsize=15) # setting y-label
# Out:
# Text(0, 0.5, 'No. of  bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar graph is used to give the comparison between two or more categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# On an average people book tickets for total stays 2-4 nights. There are minimal amount of bookings for long stays at Hotel. This might be because of some visitors coming in a country to work and are staying for one week or two, so their bookings are very low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The gained insights help creating a positive business impact as it helps to reognize most of the bookings are usually for 2-4 nights So Hotel managers might come up with some market strategies to promote more bookings for longer stays.

# %% [markdown]
# ###**11:- Bookings based on Total Night Stays**

# %%
preferred_room_type=df[['reserved_room_type']].value_counts().reset_index()
preferred_room_type
# Out:
#   reserved_room_type      0
# 0                  A  55255
# 1                  D  17201
# 2                  E   5939
# 3                  F   2750
# 4                  G   1968
# 5                  C    896
# 6                  B    765
# 7                  H    590
# 8                  L      6

# %% [markdown]
# Chart - 11

# %%
# Chart - 11 visualization code

plt.figure(figsize=(15,8))
sns.barplot(x=preferred_room_type['reserved_room_type'],y=preferred_room_type[0],order=preferred_room_type['reserved_room_type'],edgecolor='black')
add_value_label(preferred_room_type['reserved_room_type'].tolist(), preferred_room_type[0].tolist())
plt.title('Bookings Based On Different Room Types', fontsize=20,fontweight='bold')
plt.xlabel('Room TYpe', fontsize=15)
plt.ylabel('No. of  bookings', fontsize=15)
# Out:
# Text(0, 0.5, 'No. of  bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar graph is used to give the comparison between two or more categories.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Room Type A has around 25000 more bookings than all other room types combined. So Room Type A is the most preferred room type among travellers.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight show us the most preffered room type is A. SO, the hotel manager might come up some more ideas of how to attract customers for other types of room.

# %% [markdown]
# ###**12:- Bookings based on Adults & Kids**

# %%
#identifying adults count from the data
df_adults= df[['hotel','adults']][df['adults']>0].groupby(['hotel']).count()
df_adults
# Out:
#               adults
# hotel
# City Hotel     52106
# Resort Hotel   33264

# %%
#identifying kids count from the data
df_kids= df[['hotel','kids']][df['kids']>0].groupby(['hotel']).count()
df_kids
# Out:
#               kids
# hotel
# City Hotel    4956
# Resort Hotel  3825

# %% [markdown]
# Chart - 12

# %%
fig, axes = plt.subplots(1,2, figsize=(15, 8))
ax=sns.countplot(ax=axes[0],data = df, x= 'adults', hue= 'hotel') 
ax.set_title('Adults Booking',fontweight='bold')
ax=sns.countplot(data = df, ax=axes[1],x= 'kids', hue= 'hotel')
ax.set_title('Kids Booking',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Kids Booking')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Multiple bar charts are very useful for comparing the same items in different categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Majorty of the guests come in couple as we can see from count of adults plot, both the hotels acheive peak at 2.0 and spoecifically City Resort could be tagged as a "Duo/Couple-Friendly Hotel".
#
# Guests bringing children with them have more preference to City Hotel. Hence, City Hotel could also be tagged as a "Children-Friendly Hotel".
#
# Guests bringing babies with them have no such preference over Hotels, but a bit more towards Resort Hotel. So, Resort Hotel could be tagged as "Babies-Friendly Hotel"

# %% [markdown]
# ### **Bivariate Analysis** :- Bivariate analysis is analysis between two variables. One of the variables will be dependent and the other is independent. The study is analyzed between the two variables to understand to what extent the change has occurred.

# %% [markdown]
# ###**13:- What are the ADR for each of the month for both hotel types? ***

# %%
adr=df.groupby(['arrival_date_month','hotel'])['adr'].mean()
adr=adr.astype(int).reset_index() 
adr
# Out:
#    arrival_date_month         hotel  adr
# 0             January    City Hotel   87
# 1             January  Resort Hotel   50
# 2            February    City Hotel   91
# 3            February  Resort Hotel   55
# 4               March    City Hotel   95
# 5               March  Resort Hotel   58
# 6               April    City Hotel  118
# 7               April  Resort Hotel   80
# 8                 May    City Hotel  129
# 9                 May  Resort Hotel   82
# 10               June    City Hotel  125
# 11               June  Resort Hotel  113
# 12               July    City Hotel  122
# 13               July  Resort Hotel  158
# 14             August    City Hotel  126
# 15             August  Resort Hotel  189
# 16          September    City Hotel  121
# 17          September  Resort Hotel  102
# 18            October    City Hotel  110
# 19            October  Resort Hotel   65
# 20           November    City Hotel   91
# 21           November  Resort Hotel   50
# ...

# %%
months=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
adr['arrival_date_month']=pd.Categorical(adr['arrival_date_month'],categories=months,ordered=True)

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(15,8))     # setting figure size
sns.set_palette('terrain')      # setting color
sns.lineplot(x=adr['arrival_date_month'],y=adr['adr'],hue=adr['hotel'],data=df)   
plt.title('Bookings Made in Each Month for Each Hotel Type',fontweight='bold',fontsize=20)
plt.xlabel('Month',fontsize = 15)                 # setting x-label
plt.ylabel('ADR',fontsize = 15)     # setting y-label
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose line graph as line graph is a graph that is used to display change over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For Resort hotel, ADR is high in the months June,July,August as compared to City Hotels. May be Customers/People wants to spend their Summer vaccation in Resorts Hotels.
# The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# the gained insights help creating a positive business impact as it compares the adr with different months.

# %% [markdown]
# ###**14:-How much revenue earned by each of the hotel types?**

# %%
hotel_revenue=df.groupby('hotel')['revenue'].sum().reset_index(name='total_revenue')
hotel_revenue
# Out:
#           hotel  total_revenue
# 0    City Hotel       18683750
# 1  Resort Hotel       15680583

# %% [markdown]
# #### Chart - 14

# %%
# plot a bar graph to show the revenue generated by each hotel
fig, ax = plt.subplots(figsize=(20, 6))
plt.bar(hotel_revenue['hotel'].tolist(), hotel_revenue['total_revenue'].tolist())
add_value_label(hotel_revenue['hotel'].tolist(), hotel_revenue['total_revenue'].tolist())
plt.xlabel('Hotel')
plt.ylabel('Revenue')
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# ###**15:-How much revenue earned by each of the hotel types month wise?**

# %% [markdown]
# Chart - 15

# %%
plt.figure(figsize=(15,8)) 

revenue=df.groupby(['hotel','arrival_date_month'])['revenue'].sum().reset_index()
months = ['January', 'February','March','April','May','June','July','August','September','October','November','December']
df['arrival_date_month'] = pd.Categorical(df['arrival_date_month'],categories=months,ordered=True)

  # It will take the order of the month list in the df along with values
revenue['arrival_date_month']=pd.Categorical(revenue['arrival_date_month'],categories=months,ordered=True)
  #sorting
revenue=revenue.sort_values('arrival_date_month')

ax =sns.lineplot(data = df, x = 'arrival_date_month', y = 'revenue', hue = 'hotel',palette=['orange', 'green'])
ax.set_title('Revenue generated by hotels in each month',fontsize = 18, fontweight='bold')
ax.set_xlabel('Months',fontsize = 16)
ax.set_ylabel('Revenue',fontsize = 16)
plt.legend(loc='upper right')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose line graph as line graph is a graph that is used to display change over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Resort hotels and City hotels both are getting higher revenue between June to August.

# %% [markdown]
# ###**16:- What are the reservation bookings of each month based on average lead time?**

# %%
lead_time=df.groupby(['arrival_date_month','hotel'])['lead_time'].mean()
lead_time=lead_time.astype(int).reset_index()

# %%
months=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
lead_time['arrival_date_month']=pd.Categorical(lead_time['arrival_date_month'],categories=months,ordered=True)

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code
plt.figure(figsize=(15,8))     # setting figure size
sns.set_palette('terrain')      # setting color
sns.lineplot(x=lead_time['arrival_date_month'],y=lead_time['lead_time'],hue=lead_time['hotel'],data=df)   
plt.title('Bookings Made in Each Month for Each Hotel Type',fontweight='bold',fontsize=20)
plt.xlabel('Month',fontsize = 15)                 # setting x-label
plt.ylabel('Average Lead Time',fontsize = 15)     # setting y-label
# Out:
# Text(0, 0.5, 'Average Lead Time')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose line graph as line graph is a graph that is used to display change over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph we can see in city hotels there is a peak in lead time from April to July. And in resort hotels we can see two peaks in lead time, first in June and second in September

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In November, december and january where chirstmas and new year came, people most likely to celebrate with their families. So this could be the main impact on hote booking.

# %% [markdown]
# ###17:- **What is the relationship of lead time with ADR?**

# %% [markdown]
# Chart - 17

# %%
# Chart - 17 visualization code
plt.figure(figsize=(10,5))
plt.scatter( x = df['lead_time'], y = df['adr'],c ="salmon",linewidths = 0.05, edgecolor ="black", s = 50)
plt.title('Relation between ADR and Lead Time',fontsize = 20, fontweight='bold')
plt.xlabel('Lead Time',fontsize = 14)
plt.ylabel('ADR',fontsize = 14)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plot shows a relationship and a trend in the data relationship.Here we used scatter plot to determine the relationship between night stays and ADR.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see as lead time increases ADR decreases.

# %% [markdown]
# ###18:- **What is the relationship of ADR with Night stays?**

# %% [markdown]
# Chart - 18

# %%
# Chart - 18 visualization code
plt.figure(figsize=(10,5))
plt.scatter( x = df['total_night_stays'], y = df['adr'],c ="blue",linewidths = 0.05, edgecolor ="black", s = 50)
plt.title('Relation between ADR and Night Stays',fontsize = 20, fontweight='bold')
plt.xlabel('Night Stays',fontsize = 14)
plt.ylabel('ADR',fontsize = 14)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plot shows a relationship and a trend in the data relationship.Here we used scatter plot to determine the relationship between night stays and ADR.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that length of stay decreases as ADR increases.

# %% [markdown]
# ###19:- **What is the relationship between customer-waiting-list and customer cancelation?**

# %% [markdown]
# Chart - 19

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))
# a very high number of records have zero number of days in waiting list
# thats why here only non-zero data is considered
sns.kdeplot(data = df[df['days_in_waiting_list'] != 0], ax = axes[0], x = 'days_in_waiting_list', hue = 'is_canceled',shade=True)
sns.kdeplot(data = df, ax = axes[1], x = 'lead_time', hue = 'is_canceled',shade=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Lets check if lead time or number of days in waiting list motivates the customers to cancel the booking. For that we need to generate a density plot of lead time and number of days in waiting list for both cancelled and non-cancelled bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Density plot of lead time and number of days in waiting list peaks at the same point for both cancelled and non-cancelled bookings and they also attain almost identical shape. Thus we can conclude that lead time and number of days in waiting list does not affect cancellation of bookings.

# %% [markdown]
# **Multivariate Analysis :- Multivariate analysis is analysis between more than two variables**

# %% [markdown]
# #### Chart - 20 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
corrmat = df[['lead_time', 'total_night_stays', 'previous_cancellations', 'previous_bookings_not_canceled', 'total_members',
                    'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']].corr()
f, ax = plt.subplots(figsize=(12, 12))

sns.heatmap(corrmat, annot = True, fmt='.2f', annot_kws={'size': 10},  vmax=.8, square=True, cmap="BuPu")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we chose correlation heatmaps as it can be used to find potential relationships between variables and to understand the strength of these relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that lead time and length of stay have a good correlation with each other. Thus we may conclude that generally visits planned with longer stays are booked earlier than those planned with shorter stay. ADR and total number of guests also have good correlation with each other. This may be because of the increase in expenditure with the increase in the count of guests.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Higher lead time has higher chance of cancellation. Also, history of previous cancellations increases chances of cancellation.

# %% [markdown]
# #### Chart - 21 - Pair Plot

# %%
# Pair plot visualization code
sns.set_style('whitegrid')
sns.pairplot(data = df[df['adr']<500][['hotel','adr', 'total_members']],height = 5,aspect = 0.8, hue ='hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A pairs plot allows us to see both distribution of single variables and relationships between two variables. It is also a great method to identify trends for follow-up analysis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that For City hotel ADR is maximum if we compare with resort hotel, and ADR is also increases as number of people is less (<=5). If number of of people will increase they tends to book Resort Hotel.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.Cancellations are high when done through agents compared to direct bookings. Hotels need to do marketing and give special incentives for direct bookings as these may establish personal one to one relationships promoting customer loyalty.
#
# 2.Couple is the most popular accommodation type. So hotels can make arrangement and plans accordingly.
#
# 3.Repeated guests do not cancel their reservations, Of course there are some exceptions, So client have to more focused on repeated guests.
#
# 4.When the lead time exceeds about 60, guests frequently cancel their bookings (cancellation rate is higher after this point). So Client have to reduce lead time to get more ADR.
#
# 5.Client have to focus on Other type of bookings except TA/TO to increase revenue.
#
# 6.As we can see that the offline and direct booking segment has less cancelation so the hotel should prioritise them more.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. City Hotel seems to be more preferred among travellers and it also generates more revenue.
# 2. Most number of bookings are made in July and August.
# 3. Hotel bookings is highest in year 2016.
# 4. Room Type A is the most preferred room type among travellers.
# 5. Most number of bookings are made from Portugal.
# 6. Most of the guest stays for 1-4 days in the hotels.
# Resort Hotel retains more number of guests.
# 7. Around one-fourth of the total bookings gets cancelled. More cancellations are from City Hotel.
# 8. New guest tends to cancel bookings more than repeated customers.
# 9.Transient Customer type captured highest bookings share of around 82%
# 10. Corporate has the most percentage of repeated guests while TA/TO has the least whereas in the case of cancelled bookings TA/TO has the most percentage while Corporate has the least.
# 11. The length of the stay decreases as ADR increases probably to reduce the cost.
# 12. Lead time and length of stay have a good correlation with each other. ADR and total number of guests also have good correlation with each other. This may be because of the increase in expenditure with the increase in the count of guests.
# 13. Lead time increases ADR decreases.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
